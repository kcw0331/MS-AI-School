# %% [markdown]
# # Keras

# %%
from keras.datasets import mnist

# %%
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
# Out:
# ...
# 11490434/11490434 [==============================] - 0s 0us/step

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %%
len(train_labels)
# Out:
# 60000

# %%
test_images.shape
# Out:
# (10000, 28, 28)

# %%
len(test_labels)
# Out:
# 10000

# %%
from keras import models
from keras import layers

network = models.Sequential()
network.add(layers.Dense(512, activation = 'relu', input_shape = (28 * 28,))) # Dense layer를 추가 해준다. <- Input 
# input_shape은 2차원으로 만들어 줘야 되서 ,를 붙인다.
network.add(layers.Dense(10, activation = 'softmax')) # 출력값을 10개 중에 하나로 했다. <- Output , 제일 첫 층에서 input_shape을 잡아주면 나중에는 안 잡아줘도 된다.

# %%
network.compile(optimizer = 'rmsprop',
                loss = 'categorical_crossentropy',
                metrics = ['accuracy'])

# %%
# 데이터 타입의 변환
train_images = train_images.reshape((60000, 28 * 28))
train_images = train_images.astype('float32') / 255
# print(train_images[0])

test_images = test_images.reshape((10000, 28 * 28))
test_images = test_images.astype('float32') / 255

# %%
# 분류형 데이터의 설정
from tensorflow.keras.utils import to_categorical

train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

# %%
network.fit(train_images, train_labels, epochs = 5, batch_size = 128)  # 5번 반복하면서 학습을 한다.
# Out:
# Epoch 1/5
# 469/469 [==============================] - 4s 7ms/step - loss: 1.4583 - accuracy: 0.6682
# Epoch 2/5
# 469/469 [==============================] - 3s 7ms/step - loss: 0.5782 - accuracy: 0.8543
# Epoch 3/5
# 469/469 [==============================] - 3s 7ms/step - loss: 0.4073 - accuracy: 0.8901
# Epoch 4/5
# 469/469 [==============================] - 3s 7ms/step - loss: 0.3505 - accuracy: 0.9009
# Epoch 5/5
# 469/469 [==============================] - 3s 7ms/step - loss: 0.3220 - accuracy: 0.9072

# %%
test_loss, test_acc = network.evaluate(test_images, test_labels)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 50.4271 - accuracy: 0.8299

# %%
print('test_acc:', test_acc)
# Out:
# test_acc: 0.8299000263214111
